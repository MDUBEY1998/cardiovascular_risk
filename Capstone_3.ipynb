# %% [markdown]
# <a href="https://colab.research.google.com/github/MDUBEY1998/cardiovascular_risk/blob/main/Capstone_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import confusion_matrix, classification_report, roc_curve
from sklearn.metrics import make_scorer, recall_score, f1_score     
from sklearn.linear_model import LogisticRegression
from imblearn.combine import SMOTETomek
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
from xgboost import XGBRFClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.svm import SVC
import lightgbm as lgb
from lightgbm import LGBMClassifier
# !pip install scikit-optimize
from skopt.space import Real, Categorical, Integer
from skopt import BayesSearchCV
# !pip install shap
import shap
shap.initjs()
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scikit-optimize
#   Downloading scikit_optimize-0.9.0-py2.py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 9.3 MB/s
# Collecting pyaml>=16.9
#   Downloading pyaml-21.10.1-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize) (1.1.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize) (1.21.6)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize) (1.0.2)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize) (1.7.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from pyaml>=16.9->scikit-optimize) (6.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.0->scikit-optimize) (3.1.0)
# Installing collected packages: pyaml, scikit-optimize
# Successfully installed pyaml-21.10.1 scikit-optimize-0.9.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting shap
#   Downloading shap-0.41.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (569 kB)
#      |████████████████████████████████| 569 kB 26.3 MB/s
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.7/dist-packages (from shap) (21.3)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from shap) (1.7.3)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from shap) (1.5.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from shap) (1.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from shap) (1.21.6)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from shap) (0.56.2)
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.7/dist-packages (from shap) (4.64.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from shap) (1.3.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>20.9->shap) (3.0.9)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from numba->shap) (4.12.0)
# Requirement already satisfied: setuptools<60 in /usr/local/lib/python3.7/dist-packages (from numba->shap) (57.4.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba->shap) (0.39.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->shap) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->shap) (3.8.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->shap) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->shap) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->shap) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->shap) (1.1.0)
# Installing collected packages: slicer, shap
# Successfully installed shap-0.41.0 slicer-0.0.7
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Mounting drive
df = pd.read_csv('/content/drive/MyDrive/supervised ML/data_cardiovascular_risk.csv').drop(columns=['id'])

# %% [markdown]
# #**EDA**

# %%
#Let's see how our dataset looks like
df.head()
# Out:
#    age  education sex is_smoking  cigsPerDay  BPMeds  prevalentStroke  \
# 0   64        2.0   F        YES         3.0     0.0                0
# 1   36        4.0   M         NO         0.0     0.0                0
# 2   46        1.0   F        YES        10.0     0.0                0
# 3   50        1.0   M        YES        20.0     0.0                0
# 4   64        1.0   F        YES        30.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    221.0  148.0   85.0    NaN       90.0     80.0
# 1             1         0    212.0  168.0   98.0  29.77       72.0     75.0
# 2             0         0    250.0  116.0   71.0  20.35       88.0     94.0
# 3             1         0    233.0  158.0   88.0  28.26       68.0     94.0
# 4             0         0    241.0  136.5   85.0  26.42       70.0     77.0
#
#    TenYearCHD
# 0           1
# 1           0
# 2           0
# 3           1
# 4           0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3390 entries, 0 to 3389
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              3390 non-null   int64
#  1   education        3303 non-null   float64
#  2   sex              3390 non-null   object
#  3   is_smoking       3390 non-null   object
#  4   cigsPerDay       3368 non-null   float64
#  5   BPMeds           3346 non-null   float64
#  6   prevalentStroke  3390 non-null   int64
#  7   prevalentHyp     3390 non-null   int64
#  8   diabetes         3390 non-null   int64
#  9   totChol          3352 non-null   float64
#  10  sysBP            3390 non-null   float64
#  11  diaBP            3390 non-null   float64
#  12  BMI              3376 non-null   float64
#  13  heartRate        3389 non-null   float64
#  14  glucose          3086 non-null   float64
#  15  TenYearCHD       3390 non-null   int64
# dtypes: float64(9), int64(5), object(2)
# memory usage: 423.9+ KB

# %%
df.describe(include='all')
# Out:
#                 age    education   sex is_smoking   cigsPerDay       BPMeds  \
# count   3390.000000  3303.000000  3390       3390  3368.000000  3346.000000
# unique          NaN          NaN     2          2          NaN          NaN
# top             NaN          NaN     F         NO          NaN          NaN
# freq            NaN          NaN  1923       1703          NaN          NaN
# mean      49.542183     1.970936   NaN        NaN     9.069477     0.029886
# std        8.592878     1.019081   NaN        NaN    11.879078     0.170299
# min       32.000000     1.000000   NaN        NaN     0.000000     0.000000
# 25%       42.000000     1.000000   NaN        NaN     0.000000     0.000000
# 50%       49.000000     2.000000   NaN        NaN     0.000000     0.000000
# 75%       56.000000     3.000000   NaN        NaN    20.000000     0.000000
# max       70.000000     4.000000   NaN        NaN    70.000000     1.000000
#
#         prevalentStroke  prevalentHyp     diabetes      totChol       sysBP  \
# count       3390.000000   3390.000000  3390.000000  3352.000000  3390.00000
# unique              NaN           NaN          NaN          NaN         NaN
# top                 NaN           NaN          NaN          NaN         NaN
# freq                NaN           NaN          NaN          NaN         NaN
# mean           0.006490      0.315339     0.025664   237.074284   132.60118
# std            0.080309      0.464719     0.158153    45.247430    22.29203
# min            0.000000      0.000000     0.000000   107.000000    83.50000
# 25%            0.000000      0.000000     0.000000   206.000000   117.00000
# 50%            0.000000      0.000000     0.000000   234.000000   128.50000
# 75%            0.000000      1.000000     0.000000   264.000000   144.00000
# max            1.000000      1.000000     1.000000   696.000000   295.00000
#
#               diaBP          BMI    heartRate      glucose   TenYearCHD
# count   3390.000000  3376.000000  3389.000000  3086.000000  3390.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean      82.883038    25.794964    75.977279    82.086520     0.150737
# std       12.023581     4.115449    11.971868    24.244753     0.357846
# min       48.000000    15.960000    45.000000    40.000000     0.000000
# 25%       74.500000    23.020000    68.000000    71.000000     0.000000
# 50%       82.000000    25.380000    75.000000    78.000000     0.000000
# 75%       90.000000    28.040000    83.000000    87.000000     0.000000
# max      142.500000    56.800000   143.000000   394.000000     1.000000

# %%
#Checking imbalance in target variable
pd.DataFrame(df['TenYearCHD'].replace({0:'No',1:'Yes'}).value_counts()).plot(kind='pie',y='TenYearCHD',explode = (0.05, 0.05))

# %% [markdown]
# ##Null value treatment

# %%
#getting number of null values
value_nulldf = pd.DataFrame(df.isnull().sum(),columns=['value_counts'])
percent_null_df = pd.DataFrame(round(df.isnull().sum() * 100 / df.shape[0],2),columns=['percentage'])
fdf=pd.concat([value_nulldf, percent_null_df],axis=1)
fdf[fdf['value_counts']!=0]
# Out:
#             value_counts  percentage
# education             87        2.57
# cigsPerDay            22        0.65
# BPMeds                44        1.30
# totChol               38        1.12
# BMI                   14        0.41
# heartRate              1        0.03
# glucose              304        8.97

# %%
plt.figure(figsize=(10,8))
df[df.columns[df.isnull().any()].tolist()].boxplot(vert=False,figsize=(10,6)) #evaluating values to impute in null values
#Since almost all the datas are right skewed, we impute median value

# %%
##creating a copy of original untethered dataset
df1 = df.copy()

# %%
#imputing null values with median
na_columns = df1.columns[df1.isnull().any()].tolist()
for col in na_columns:
  df1[col].fillna(df1[col].median(),inplace = True)

# %% [markdown]
# #Outlier treatment

# %%
#Now we divide the columns into numerical and categorical
categorical_columns = [col for col in df1.columns if len(df[col].unique())<=4]
numerical_columns = list(set(df1.columns) - set(categorical_columns))

# %%
#getting distplot of numeric features
for i,col in enumerate(numerical_columns):
  plt.subplot(3,3,i+1)
  g=sns.distplot(df1[col], rug=True)
  g.figure.set_size_inches(18,18)
  plt.title(col)

# %%
for i,col in enumerate(numerical_columns):
  plt.subplot(3,3,i+1)
  g=sns.boxplot(df1[col])
  g.figure.set_size_inches(10,12)

# %%
before_otlier_treatment_df = df1.copy()

# %%
#a function to replace outliers with a value
def replace_outliers(dataframe, columns):
  '''Takes dataframe and columns as a list then replaces them with value. value is median'''
  for col in columns:
    q1, q3 = dataframe[col].quantile([0.25,0.75])
    lower_limit = q1 - 1.5 * (q3 - q1)
    upper_limit = q3 + 1.5 * (q3 - q1)
    dataframe[col] = np.where(dataframe[col]<lower_limit,df1[col].median(),dataframe[col])
    dataframe[col] = np.where(dataframe[col]>upper_limit,df1[col].median(),dataframe[col])
  return dataframe.head()

# %%
#removing outliers
replace_outliers(df1,numerical_columns)
# Out:
#     age  education sex is_smoking  cigsPerDay  BPMeds  prevalentStroke  \
# 0  64.0        2.0   F        YES         3.0     0.0                0
# 1  36.0        4.0   M         NO         0.0     0.0                0
# 2  46.0        1.0   F        YES        10.0     0.0                0
# 3  50.0        1.0   M        YES        20.0     0.0                0
# 4  64.0        1.0   F        YES        30.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    221.0  148.0   85.0  25.38       90.0     80.0
# 1             1         0    212.0  168.0   98.0  29.77       72.0     75.0
# 2             0         0    250.0  116.0   71.0  20.35       88.0     94.0
# 3             1         0    233.0  158.0   88.0  28.26       68.0     94.0
# 4             0         0    241.0  136.5   85.0  26.42       70.0     77.0
#
#    TenYearCHD
# 0           1
# 1           0
# 2           0
# 3           1
# 4           0

# %%
# now we plot the graphs for before and after outlier treatment
for col in numerical_columns:
  fig,ax = plt.subplots(1,4,constrained_layout = True)
  fig.set_size_inches(15,3)
  sns.distplot(before_otlier_treatment_df[col], ax = ax[0]).set(title='before')
  sns.boxplot(before_otlier_treatment_df[col],ax = ax[1]).set(title='before')
  #after outlier treatment
  sns.distplot(df1[col],ax=ax[2]).set(title='after')
  sns.boxplot(df1[col],ax=ax[3]).set(title='after')
  plt.suptitle(f'{col}', weight = 'bold')
  plt.show()
#at this point outliers from the numerical columns has been treated.... and now we work with categorical columns.

# %% [markdown]
# #Working with non-numeric values

# %%
 #So, categorical columns have no null values
df1[categorical_columns].isnull().sum()
# Out:
# sex                0
# is_smoking         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# TenYearCHD         0
# dtype: int64

# %%
df_cat=df[categorical_columns]

# %%
for i,col in enumerate(categorical_columns):
  t_df = pd.DataFrame(df1[col].value_counts())
  palette_color = sns.color_palette('pastel')
  keys = list(t_df.index)
  data = list(t_df[col])
  plt.rcParams["figure.figsize"] = (14,6)
  plt.subplot(2,4,i+1)
  plt.pie(data, labels=keys, colors=palette_color, autopct='%.0f%%')
  plt.title(col)       #this is the distribution and we don't have any null values in categorical columns, we do need tofix imbalance

# %%
#is_smoking is available from the number_of_cigs column so we remove it
#furthermore we change the sex column to numerical
df1.replace({'sex':{'M':1,'F':0}},inplace = True)
df1=df1.drop(columns=['is_smoking'])

# %%
len(list(df1.columns))
# Out:
# 15

# %% [markdown]
# #**Verifying Logistic regression prerequisites**

# %%
for i,col in enumerate(list(df1.columns)):
  plt.subplot(5,3,i+1)
  df1[col].hist(bins=50,figsize=(18,18),alpha=0.55)
  mean=df1[col].mean()
  median=df1[col].median()
  plt.axvline(mean, color='green', linestyle='dashed', linewidth=1,label='mean')
  plt.axvline(median,color='red',linestyle='dashed', linewidth=1,label='median')
  plt.legend()
  plt.title(col)

# %%
#colors=['coral','cyan','orange','plum','teal','gold','indianred','lime','indigo','seagreen','cornflowerblue','lawngreen','deepskyblue','chocolate']
for i, col in enumerate(list(df1.columns)):
  plt.subplot(3,5,i+1)
  var=df1[col]
  g=sns.regplot(var, df1['TenYearCHD'],line_kws={"color": "red"},color='cornflowerblue')
  g.figure.set_size_inches(20,14)
  plt.title(col)   #So, almost all variables share some kind of relation with target variable
                    # Thus, logistic regression should work fine

# %% [markdown]
# #**Preparing data for Logistic regression**

# %%
plt.figure(figsize=(18,9))
plot=sns.heatmap(df1.corr(), annot=True, cmap='coolwarm')
plot.set_xticklabels(plot.get_xticklabels(), rotation=30, horizontalalignment='right')
plt.show()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def get_VIF(X):
  '''Gives the VIF values of the variables for a dataframe'''
  vif_data = pd.DataFrame()
  vif_data["feature"] = X.columns
    
  # calculating VIF for each feature
  vif_data["VIF"] = [variance_inflation_factor(X.values, i)
                            for i in range(len(X.columns))]
  return vif_data

# %%
independent_var = list(set(df1.columns)-{'TenYearCHD'})
dependent_var = ['TenYearCHD']

# %%
df2 = df1.copy()

# %%
df1['mean_BP'] = (df1['sysBP'] + df1['diaBP']) / 2
#inrease in glucose results in increase of BMI, so we drop BMI
#A higher pulse rate and elevated blood pressure are often associated with high cholesterol
df1['chol'] = 0.25*df1['heartRate'] + 0.75* df1['mean_BP'] 
# Hyperinsulinemia and elevated blood glucose levels have both been associated with a higher heart rate
df1['glucose_age'] =  0.6 * df1['age'] + 0.4 * df1['glucose']
df1['glucose_age_chol'] = df1['glucose_age'] + df1['chol'] / 2

# %%
get_VIF(df1.drop(columns=['sysBP','diaBP','BMI','heartRate','mean_BP','totChol','age','glucose','glucose_age','chol','TenYearCHD']))
# Out:
#             feature       VIF
# 0         education  4.615076
# 1               sex  1.974453
# 2        cigsPerDay  1.765727
# 3            BPMeds  1.120071
# 4   prevalentStroke  1.024471
# 5      prevalentHyp  1.728712
# 6          diabetes  1.042041
# 7  glucose_age_chol  6.538264

# %%
df1 = df1.drop(columns=['sysBP','diaBP','BMI','heartRate','mean_BP','totChol','age','glucose','glucose_age','chol','TenYearCHD'])

# %% [markdown]
# #**Train Test split and oversampling for logistic regression**

# %%
#initilizing minmax scaler
scaler = MinMaxScaler()
X=df1
Y=df2['TenYearCHD']

#splitting the dataset

X_train, X_test, Y_train, Y_test = train_test_split( X,Y , test_size = 0.2, random_state = 0, stratify=Y)

#standardizing

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
print(f'Before X_train : {X_train.shape}')
print(f'Before Y_train :\n{Y_train.value_counts()}')
#Handling class imbalance by oversampling it using smote and removinh tomek links
X_smote, Y_smote = SMOTETomek(random_state=42).fit_resample(X_train,Y_train)
print(f'After X_smote : {X_smote.shape}')
print(f'After Y_smote :\n{Y_smote.value_counts()}')
# Out:
# Before X_train : (2712, 8)
# Before Y_train :
# 0    2303
# 1     409
# Name: TenYearCHD, dtype: int64
# After X_smote : (3876, 8)
# After Y_smote :
# 0    1938
# 1    1938
# Name: TenYearCHD, dtype: int64

# %% [markdown]
# #**Defining function to get some of the metrics**

# %%
def get_some_metric(model):
  #predicting test set
  Y_pred = model.predict(X_test)
  Y_pred_proba = model.predict_proba(X_test)[::,1]
  fpr, tpr, _ = metrics.roc_curve(Y_test,  Y_pred_proba)
  #prediction train set
  Y_train_pred = model.predict(X_train)
  Y_train_pred_proba = model.predict_proba(X_train)[::,1]
  fpr_train, tpr_train, _train = metrics.roc_curve(Y_train,  Y_train_pred_proba)
  #plotting confusion matrix  
  plt.subplot(2,2,1)
  sns.heatmap(confusion_matrix(Y_train_pred,Y_train),annot=True, cmap='coolwarm',fmt='g')
  plt.gcf().set_size_inches(25,16)
  plt.ylabel('Predicted Label')
  plt.xlabel('True Label')
  plt.title('train_data_confusion_matrix',weight='bold')
  #plt.show()

  plt.subplot(2,2,2)
  sns.heatmap(confusion_matrix(Y_pred,Y_test),annot=True, cmap='Blues',fmt='g')
  plt.gcf().set_size_inches(25,16)
  plt.ylabel('Predicted Label')
  plt.xlabel('True Label')
  plt.title('test_data_confusion_matrix',weight='bold')
  #plt.show()

  plt.subplot(2,2,3)
  #create ROC curve
  plt.plot([0,1],[0,1],'k--')
  plt.plot(fpr,tpr)
  plt.ylabel('True Positive Rate')
  plt.xlabel('False Positive Rate')
  plt.title('ROC-AUC test set',weight='bold')
  plt.gcf().set_size_inches(25,16)
  #plt.show()

  plt.subplot(2,2,4)
  #create ROC curve
  plt.plot([0,1],[0,1],'k--')
  plt.plot(fpr_train,tpr_train)
  plt.ylabel('True Positive Rate')
  plt.xlabel('False Positive Rate')
  plt.title('ROC-AUC train set',weight='bold')
  plt.gcf().set_size_inches(25,16)
  plt.show()

# %% [markdown]
# #**Logistic Regression Implementation**

# %%
#Now, we fit the models first is Linear regression
log_reg = LogisticRegression()
penalty = ['l1', 'l2', 'elasticnet']
C_range = np.logspace(-3,10,10)
params_grid = dict(penalty = penalty, C=C_range)
logistic_reg_cv = GridSearchCV(log_reg,params_grid,cv=5,verbose=3)
logistic_reg_cv.fit(X_smote,Y_smote)

print("tuned hpyerparameters :(best parameters) ",logistic_reg_cv.best_params_)
print("accuracy :",logistic_reg_cv.best_score_) #tuned hpyerparameters :(best parameters)  {'C': 0.774263682681127, 'penalty': 'l2'}
                                                #accuracy : 0.6612391429136044
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV 1/5] END .................C=0.001, penalty=l1;, score=nan total time=   0.0s
# [CV 2/5] END .................C=0.001, penalty=l1;, score=nan total time=   0.0s
# [CV 3/5] END .................C=0.001, penalty=l1;, score=nan total time=   0.0s
# [CV 4/5] END .................C=0.001, penalty=l1;, score=nan total time=   0.0s
# [CV 5/5] END .................C=0.001, penalty=l1;, score=nan total time=   0.0s
# [CV 1/5] END ...............C=0.001, penalty=l2;, score=0.671 total time=   0.0s
# [CV 2/5] END ...............C=0.001, penalty=l2;, score=0.639 total time=   0.0s
# [CV 3/5] END ...............C=0.001, penalty=l2;, score=0.676 total time=   0.0s
# [CV 4/5] END ...............C=0.001, penalty=l2;, score=0.627 total time=   0.0s
# [CV 5/5] END ...............C=0.001, penalty=l2;, score=0.621 total time=   0.0s
# [CV 1/5] END .........C=0.001, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 2/5] END .........C=0.001, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 3/5] END .........C=0.001, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 4/5] END .........C=0.001, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 5/5] END .........C=0.001, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 1/5] END ..C=0.027825594022071243, penalty=l1;, score=nan total time=   0.0s
# [CV 2/5] END ..C=0.027825594022071243, penalty=l1;, score=nan total time=   0.0s
# [CV 3/5] END ..C=0.027825594022071243, penalty=l1;, score=nan total time=   0.0s
# [CV 4/5] END ..C=0.027825594022071243, penalty=l1;, score=nan total time=   0.0s
# [CV 5/5] END ..C=0.027825594022071243, penalty=l1;, score=nan total time=   0.0s
# [CV 1/5] END C=0.027825594022071243, penalty=l2;, score=0.687 total time=   0.0s
# [CV 2/5] END C=0.027825594022071243, penalty=l2;, score=0.640 total time=   0.0s
# [CV 3/5] END C=0.027825594022071243, penalty=l2;, score=0.685 total time=   0.0s
# [CV 4/5] END C=0.027825594022071243, penalty=l2;, score=0.659 total time=   0.0s
# [CV 5/5] END C=0.027825594022071243, penalty=l2;, score=0.640 total time=   0.0s
# [CV 1/5] END C=0.027825594022071243, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 2/5] END C=0.027825594022071243, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 3/5] END C=0.027825594022071243, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 4/5] END C=0.027825594022071243, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 5/5] END C=0.027825594022071243, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 1/5] END .....C=0.774263682681127, penalty=l1;, score=nan total time=   0.0s
# [CV 2/5] END .....C=0.774263682681127, penalty=l1;, score=nan total time=   0.0s
# [CV 3/5] END .....C=0.774263682681127, penalty=l1;, score=nan total time=   0.0s
# [CV 4/5] END .....C=0.774263682681127, penalty=l1;, score=nan total time=   0.0s
# [CV 5/5] END .....C=0.774263682681127, penalty=l1;, score=nan total time=   0.0s
# [CV 1/5] END ...C=0.774263682681127, penalty=l2;, score=0.683 total time=   0.1s
# [CV 2/5] END ...C=0.774263682681127, penalty=l2;, score=0.630 total time=   0.1s
# [CV 3/5] END ...C=0.774263682681127, penalty=l2;, score=0.693 total time=   0.0s
# [CV 4/5] END ...C=0.774263682681127, penalty=l2;, score=0.646 total time=   0.1s
# [CV 5/5] END ...C=0.774263682681127, penalty=l2;, score=0.653 total time=   0.1s
# [CV 1/5] END C=0.774263682681127, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 2/5] END C=0.774263682681127, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 3/5] END C=0.774263682681127, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 4/5] END C=0.774263682681127, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 5/5] END C=0.774263682681127, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 1/5] END .....C=21.54434690031882, penalty=l1;, score=nan total time=   0.0s
# [CV 2/5] END .....C=21.54434690031882, penalty=l1;, score=nan total time=   0.0s
# [CV 3/5] END .....C=21.54434690031882, penalty=l1;, score=nan total time=   0.0s
# [CV 4/5] END .....C=21.54434690031882, penalty=l1;, score=nan total time=   0.0s
# [CV 5/5] END .....C=21.54434690031882, penalty=l1;, score=nan total time=   0.0s
# [CV 1/5] END ...C=21.54434690031882, penalty=l2;, score=0.686 total time=   0.1s
# [CV 2/5] END ...C=21.54434690031882, penalty=l2;, score=0.635 total time=   0.0s
# [CV 3/5] END ...C=21.54434690031882, penalty=l2;, score=0.684 total time=   0.0s
# [CV 4/5] END ...C=21.54434690031882, penalty=l2;, score=0.645 total time=   0.1s
# [CV 5/5] END ...C=21.54434690031882, penalty=l2;, score=0.644 total time=   0.1s
# [CV 1/5] END C=21.54434690031882, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 2/5] END C=21.54434690031882, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 3/5] END C=21.54434690031882, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 4/5] END C=21.54434690031882, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 5/5] END C=21.54434690031882, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 1/5] END .....C=599.4842503189409, penalty=l1;, score=nan total time=   0.0s
# [CV 2/5] END .....C=599.4842503189409, penalty=l1;, score=nan total time=   0.0s
# [CV 3/5] END .....C=599.4842503189409, penalty=l1;, score=nan total time=   0.0s
# [CV 4/5] END .....C=599.4842503189409, penalty=l1;, score=nan total time=   0.0s
# [CV 5/5] END .....C=599.4842503189409, penalty=l1;, score=nan total time=   0.0s
# [CV 1/5] END ...C=599.4842503189409, penalty=l2;, score=0.686 total time=   0.1s
# [CV 2/5] END ...C=599.4842503189409, penalty=l2;, score=0.636 total time=   0.1s
# [CV 3/5] END ...C=599.4842503189409, penalty=l2;, score=0.683 total time=   0.1s
# [CV 4/5] END ...C=599.4842503189409, penalty=l2;, score=0.645 total time=   0.1s
# [CV 5/5] END ...C=599.4842503189409, penalty=l2;, score=0.644 total time=   0.1s
# [CV 1/5] END C=599.4842503189409, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 2/5] END C=599.4842503189409, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 3/5] END C=599.4842503189409, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 4/5] END C=599.4842503189409, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 5/5] END C=599.4842503189409, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 1/5] END ....C=16681.005372000593, penalty=l1;, score=nan total time=   0.0s
# [CV 2/5] END ....C=16681.005372000593, penalty=l1;, score=nan total time=   0.0s
# [CV 3/5] END ....C=16681.005372000593, penalty=l1;, score=nan total time=   0.0s
# [CV 4/5] END ....C=16681.005372000593, penalty=l1;, score=nan total time=   0.0s
# [CV 5/5] END ....C=16681.005372000593, penalty=l1;, score=nan total time=   0.0s
# [CV 1/5] END ..C=16681.005372000593, penalty=l2;, score=0.686 total time=   0.1s
# [CV 2/5] END ..C=16681.005372000593, penalty=l2;, score=0.636 total time=   0.0s
# [CV 3/5] END ..C=16681.005372000593, penalty=l2;, score=0.683 total time=   0.0s
# [CV 4/5] END ..C=16681.005372000593, penalty=l2;, score=0.645 total time=   0.0s
# [CV 5/5] END ..C=16681.005372000593, penalty=l2;, score=0.644 total time=   0.0s
# [CV 1/5] END C=16681.005372000593, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 2/5] END C=16681.005372000593, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 3/5] END C=16681.005372000593, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 4/5] END C=16681.005372000593, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 5/5] END C=16681.005372000593, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 1/5] END .....C=464158.8833612772, penalty=l1;, score=nan total time=   0.0s
# [CV 2/5] END .....C=464158.8833612772, penalty=l1;, score=nan total time=   0.0s
# [CV 3/5] END .....C=464158.8833612772, penalty=l1;, score=nan total time=   0.0s
# [CV 4/5] END .....C=464158.8833612772, penalty=l1;, score=nan total time=   0.0s
# [CV 5/5] END .....C=464158.8833612772, penalty=l1;, score=nan total time=   0.0s
# [CV 1/5] END ...C=464158.8833612772, penalty=l2;, score=0.686 total time=   0.1s
# [CV 2/5] END ...C=464158.8833612772, penalty=l2;, score=0.636 total time=   0.0s
# [CV 3/5] END ...C=464158.8833612772, penalty=l2;, score=0.683 total time=   0.0s
# [CV 4/5] END ...C=464158.8833612772, penalty=l2;, score=0.645 total time=   0.0s
# [CV 5/5] END ...C=464158.8833612772, penalty=l2;, score=0.644 total time=   0.1s
# [CV 1/5] END C=464158.8833612772, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 2/5] END C=464158.8833612772, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 3/5] END C=464158.8833612772, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 4/5] END C=464158.8833612772, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 5/5] END C=464158.8833612772, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 1/5] END ....C=12915496.650148828, penalty=l1;, score=nan total time=   0.0s
# [CV 2/5] END ....C=12915496.650148828, penalty=l1;, score=nan total time=   0.0s
# [CV 3/5] END ....C=12915496.650148828, penalty=l1;, score=nan total time=   0.0s
# [CV 4/5] END ....C=12915496.650148828, penalty=l1;, score=nan total time=   0.0s
# [CV 5/5] END ....C=12915496.650148828, penalty=l1;, score=nan total time=   0.0s
# [CV 1/5] END ..C=12915496.650148828, penalty=l2;, score=0.686 total time=   0.1s
# [CV 2/5] END ..C=12915496.650148828, penalty=l2;, score=0.636 total time=   0.0s
# [CV 3/5] END ..C=12915496.650148828, penalty=l2;, score=0.683 total time=   0.1s
# [CV 4/5] END ..C=12915496.650148828, penalty=l2;, score=0.645 total time=   0.1s
# [CV 5/5] END ..C=12915496.650148828, penalty=l2;, score=0.644 total time=   0.1s
# [CV 1/5] END C=12915496.650148828, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 2/5] END C=12915496.650148828, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 3/5] END C=12915496.650148828, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 4/5] END C=12915496.650148828, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 5/5] END C=12915496.650148828, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 1/5] END .....C=359381366.3804626, penalty=l1;, score=nan total time=   0.0s
# [CV 2/5] END .....C=359381366.3804626, penalty=l1;, score=nan total time=   0.0s
# [CV 3/5] END .....C=359381366.3804626, penalty=l1;, score=nan total time=   0.0s
# [CV 4/5] END .....C=359381366.3804626, penalty=l1;, score=nan total time=   0.0s
# [CV 5/5] END .....C=359381366.3804626, penalty=l1;, score=nan total time=   0.0s
# [CV 1/5] END ...C=359381366.3804626, penalty=l2;, score=0.686 total time=   0.1s
# [CV 2/5] END ...C=359381366.3804626, penalty=l2;, score=0.636 total time=   0.1s
# [CV 3/5] END ...C=359381366.3804626, penalty=l2;, score=0.683 total time=   0.1s
# [CV 4/5] END ...C=359381366.3804626, penalty=l2;, score=0.645 total time=   0.0s
# [CV 5/5] END ...C=359381366.3804626, penalty=l2;, score=0.644 total time=   0.1s
# [CV 1/5] END C=359381366.3804626, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 2/5] END C=359381366.3804626, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 3/5] END C=359381366.3804626, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 4/5] END C=359381366.3804626, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 5/5] END C=359381366.3804626, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 1/5] END .........C=10000000000.0, penalty=l1;, score=nan total time=   0.0s
# [CV 2/5] END .........C=10000000000.0, penalty=l1;, score=nan total time=   0.0s
# [CV 3/5] END .........C=10000000000.0, penalty=l1;, score=nan total time=   0.0s
# [CV 4/5] END .........C=10000000000.0, penalty=l1;, score=nan total time=   0.0s
# [CV 5/5] END .........C=10000000000.0, penalty=l1;, score=nan total time=   0.0s
# [CV 1/5] END .......C=10000000000.0, penalty=l2;, score=0.686 total time=   0.1s
# [CV 2/5] END .......C=10000000000.0, penalty=l2;, score=0.636 total time=   0.1s
# [CV 3/5] END .......C=10000000000.0, penalty=l2;, score=0.683 total time=   0.0s
# [CV 4/5] END .......C=10000000000.0, penalty=l2;, score=0.645 total time=   0.0s
# [CV 5/5] END .......C=10000000000.0, penalty=l2;, score=0.644 total time=   0.0s
# [CV 1/5] END .C=10000000000.0, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 2/5] END .C=10000000000.0, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 3/5] END .C=10000000000.0, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 4/5] END .C=10000000000.0, penalty=elasticnet;, score=nan total time=   0.0s
# [CV 5/5] END .C=10000000000.0, penalty=elasticnet;, score=nan total time=   0.0s
# tuned hpyerparameters :(best parameters)  {'C': 0.027825594022071243, 'penalty': 'l2'}
# accuracy : 0.6622743598270702

# %%
get_some_metric(logistic_reg_cv)

# %%
#get classification reports
Y_pred = logistic_reg_cv.predict(X_test)
clf_rpt_test = pd.DataFrame(classification_report(Y_pred,Y_test,output_dict=True)).style.set_caption("Classification Report of test output")
#test classification report
clf_rpt_train = pd.DataFrame(classification_report(logistic_reg_cv.predict(X_train),Y_train,output_dict=True)).style.set_caption("Classification Report of train set")
#train classification report

# %%
clf_rpt_train #train classification report
# Out:
# <style type="text/css">
# </style>
# <table id="T_48b82_" class="dataframe">
#   <caption>Classification Report of train set</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >accuracy</th>
#       <th class="col_heading level0 col3" >macro avg</th>
#       <th class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48b82_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_48b82_row0_col0" class="data row0 col0" >0.656969</td>
#       <td id="T_48b82_row0_col1" class="data row0 col1" >0.625917</td>
#       <td id="T_48b82_row0_col2" class="data row0 col2" >0.652286</td>
#       <td id="T_48b82_row0_col3" class="data row0 col3" >0.641443</td>
#       <td id="T_48b82_row0_col4" class="data row0 col4" >0.644993</td>
#     </tr>
#     <tr>
#       <th id="T_48b82_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_48b82_row1_col0" class="data row1 col0" >0.908163</td>
#       <td id="T_48b82_row1_col1" class="data row1 col1" >0.244742</td>
#       <td id="T_48b82_row1_col2" class="data row1 col2" >0.652286</td>
#       <td id="T_48b82_row1_col3" class="data row1 col3" >0.576453</td>
#       <td id="T_48b82_row1_col4" class="data row1 col4" >0.652286</td>
#     </tr>
#     <tr>
#       <th id="T_48b82_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_48b82_row2_col0" class="data row2 col0" >0.762409</td>
#       <td id="T_48b82_row2_col1" class="data row2 col1" >0.351890</td>
#       <td id="T_48b82_row2_col2" class="data row2 col2" >0.652286</td>
#       <td id="T_48b82_row2_col3" class="data row2 col3" >0.557149</td>
#       <td id="T_48b82_row2_col4" class="data row2 col4" >0.604074</td>
#     </tr>
#     <tr>
#       <th id="T_48b82_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_48b82_row3_col0" class="data row3 col0" >1666.000000</td>
#       <td id="T_48b82_row3_col1" class="data row3 col1" >1046.000000</td>
#       <td id="T_48b82_row3_col2" class="data row3 col2" >0.652286</td>
#       <td id="T_48b82_row3_col3" class="data row3 col3" >2712.000000</td>
#       <td id="T_48b82_row3_col4" class="data row3 col4" >2712.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
clf_rpt_test #test classification report
# Out:
# <style type="text/css">
# </style>
# <table id="T_c6fd8_" class="dataframe">
#   <caption>Classification Report of test output</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >accuracy</th>
#       <th class="col_heading level0 col3" >macro avg</th>
#       <th class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6fd8_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_c6fd8_row0_col0" class="data row0 col0" >0.680556</td>
#       <td id="T_c6fd8_row0_col1" class="data row0 col1" >0.519608</td>
#       <td id="T_c6fd8_row0_col2" class="data row0 col2" >0.656342</td>
#       <td id="T_c6fd8_row0_col3" class="data row0 col3" >0.600082</td>
#       <td id="T_c6fd8_row0_col4" class="data row0 col4" >0.624295</td>
#     </tr>
#     <tr>
#       <th id="T_c6fd8_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_c6fd8_row1_col0" class="data row1 col0" >0.888889</td>
#       <td id="T_c6fd8_row1_col1" class="data row1 col1" >0.223629</td>
#       <td id="T_c6fd8_row1_col2" class="data row1 col2" >0.656342</td>
#       <td id="T_c6fd8_row1_col3" class="data row1 col3" >0.556259</td>
#       <td id="T_c6fd8_row1_col4" class="data row1 col4" >0.656342</td>
#     </tr>
#     <tr>
#       <th id="T_c6fd8_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_c6fd8_row2_col0" class="data row2 col0" >0.770895</td>
#       <td id="T_c6fd8_row2_col1" class="data row2 col1" >0.312684</td>
#       <td id="T_c6fd8_row2_col2" class="data row2 col2" >0.656342</td>
#       <td id="T_c6fd8_row2_col3" class="data row2 col3" >0.541790</td>
#       <td id="T_c6fd8_row2_col4" class="data row2 col4" >0.610724</td>
#     </tr>
#     <tr>
#       <th id="T_c6fd8_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_c6fd8_row3_col0" class="data row3 col0" >441.000000</td>
#       <td id="T_c6fd8_row3_col1" class="data row3 col1" >237.000000</td>
#       <td id="T_c6fd8_row3_col2" class="data row3 col2" >0.656342</td>
#       <td id="T_c6fd8_row3_col3" class="data row3 col3" >678.000000</td>
#       <td id="T_c6fd8_row3_col4" class="data row3 col4" >678.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Fits the explainer
explainer = shap.Explainer(logistic_reg_cv.predict, X_test)
# Calculates the SHAP values
shap_values = explainer(X)
# Out:
# Exact explainer: 3391it [00:15, 140.36it/s]

# %%
shap.plots.beeswarm(shap_values)

# %% [markdown]
# #**Gaussian NB Implementation**

# %%
from sklearn.naive_bayes import GaussianNB
clf= GaussianNB()
clf.fit(X_smote,Y_smote)
# Out:
# GaussianNB()

# %%
get_some_metric(clf)

# %% [markdown]
# #**Train Test Split and oversampling for SVC**

# %%
scaler = MinMaxScaler()
X=df2.drop(columns=['TenYearCHD'])
Y=df2['TenYearCHD']
#splitting the dataset

X_train, X_test, Y_train, Y_test = train_test_split( X,Y , test_size = 0.2, random_state = 0, stratify=Y)

#standardizing
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
print(f'Before X_train : {X_train.shape}')
print(f'Before Y_train :\n{Y_train.value_counts()}')

#Handling class imbalance by oversampling it using smote and removinh tomek links
X_smote, Y_smote = SMOTETomek(random_state=42).fit_resample(X_train,Y_train)
print(f'After X_smote : {X_smote.shape}')
print(f'After Y_smote :\n{Y_smote.value_counts()}')
# Out:
# Before X_train : (2712, 14)
# Before Y_train :
# 0    2303
# 1     409
# Name: TenYearCHD, dtype: int64
# After X_smote : (4586, 14)
# After Y_smote :
# 0    2293
# 1    2293
# Name: TenYearCHD, dtype: int64

# %% [markdown]
# #**Support vector classifier implementation**

# %%
classifier = SVC(random_state = 0, probability = True)
C_range = [170]
kernel = ['rbf']
#degree=[1]
gamma_range = [0.001]
#gamma_range = np.append(np.logspace(-5,2,10),None)
params_grid_svc = dict(C = C_range, kernel = kernel, gamma = gamma_range)
clf_svc_grid = GridSearchCV(classifier,params_grid_svc,scoring='roc_auc',cv=3,verbose=3)
clf_svc_grid.fit(X_smote,Y_smote)
print(f"The best parameters are {clf_svc_grid.best_params_} with a score of {clf_svc_grid.best_score_}")
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ....C=170, gamma=0.001, kernel=rbf;, score=0.720 total time=   2.4s
# [CV 2/3] END ....C=170, gamma=0.001, kernel=rbf;, score=0.732 total time=   2.5s
# [CV 3/3] END ....C=170, gamma=0.001, kernel=rbf;, score=0.724 total time=   2.5s
# The best parameters are {'C': 170, 'gamma': 0.001, 'kernel': 'rbf'} with a score of 0.7254054472740429

# %%
get_some_metric(clf_svc_grid)

# %%
#get classification reports
Y_pred = clf_svc_grid.predict(X_test)
clf_rpt_test = pd.DataFrame(classification_report(Y_pred,Y_test,output_dict=True)).style.set_caption("Classification Report of test output")
#test classification report
clf_rpt_train = pd.DataFrame(classification_report(clf_svc_grid.predict(X_train),Y_train,output_dict=True)).style.set_caption("Classification Report of train set")

# %%
#train classification report
clf_rpt_train
# Out:
# <style type="text/css">
# </style>
# <table id="T_95ef0_" class="dataframe">
#   <caption>Classification Report of train set</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >accuracy</th>
#       <th class="col_heading level0 col3" >macro avg</th>
#       <th class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95ef0_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_95ef0_row0_col0" class="data row0 col0" >0.626140</td>
#       <td id="T_95ef0_row0_col1" class="data row0 col1" >0.701711</td>
#       <td id="T_95ef0_row0_col2" class="data row0 col2" >0.637537</td>
#       <td id="T_95ef0_row0_col3" class="data row0 col3" >0.663926</td>
#       <td id="T_95ef0_row0_col4" class="data row0 col4" >0.658130</td>
#     </tr>
#     <tr>
#       <th id="T_95ef0_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_95ef0_row1_col0" class="data row1 col0" >0.921995</td>
#       <td id="T_95ef0_row1_col1" class="data row1 col1" >0.250000</td>
#       <td id="T_95ef0_row1_col2" class="data row1 col2" >0.637537</td>
#       <td id="T_95ef0_row1_col3" class="data row1 col3" >0.585997</td>
#       <td id="T_95ef0_row1_col4" class="data row1 col4" >0.637537</td>
#     </tr>
#     <tr>
#       <th id="T_95ef0_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_95ef0_row2_col0" class="data row2 col0" >0.745798</td>
#       <td id="T_95ef0_row2_col1" class="data row2 col1" >0.368658</td>
#       <td id="T_95ef0_row2_col2" class="data row2 col2" >0.637537</td>
#       <td id="T_95ef0_row2_col3" class="data row2 col3" >0.557228</td>
#       <td id="T_95ef0_row2_col4" class="data row2 col4" >0.586153</td>
#     </tr>
#     <tr>
#       <th id="T_95ef0_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_95ef0_row3_col0" class="data row3 col0" >1564.000000</td>
#       <td id="T_95ef0_row3_col1" class="data row3 col1" >1148.000000</td>
#       <td id="T_95ef0_row3_col2" class="data row3 col2" >0.637537</td>
#       <td id="T_95ef0_row3_col3" class="data row3 col3" >2712.000000</td>
#       <td id="T_95ef0_row3_col4" class="data row3 col4" >2712.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
clf_rpt_test
# Out:
# <style type="text/css">
# </style>
# <table id="T_b400c_" class="dataframe">
#   <caption>Classification Report of test output</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >accuracy</th>
#       <th class="col_heading level0 col3" >macro avg</th>
#       <th class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b400c_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_b400c_row0_col0" class="data row0 col0" >0.644097</td>
#       <td id="T_b400c_row0_col1" class="data row0 col1" >0.676471</td>
#       <td id="T_b400c_row0_col2" class="data row0 col2" >0.648968</td>
#       <td id="T_b400c_row0_col3" class="data row0 col3" >0.660284</td>
#       <td id="T_b400c_row0_col4" class="data row0 col4" >0.657180</td>
#     </tr>
#     <tr>
#       <th id="T_b400c_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_b400c_row1_col0" class="data row1 col0" >0.918317</td>
#       <td id="T_b400c_row1_col1" class="data row1 col1" >0.251825</td>
#       <td id="T_b400c_row1_col2" class="data row1 col2" >0.648968</td>
#       <td id="T_b400c_row1_col3" class="data row1 col3" >0.585071</td>
#       <td id="T_b400c_row1_col4" class="data row1 col4" >0.648968</td>
#     </tr>
#     <tr>
#       <th id="T_b400c_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_b400c_row2_col0" class="data row2 col0" >0.757143</td>
#       <td id="T_b400c_row2_col1" class="data row2 col1" >0.367021</td>
#       <td id="T_b400c_row2_col2" class="data row2 col2" >0.648968</td>
#       <td id="T_b400c_row2_col3" class="data row2 col3" >0.562082</td>
#       <td id="T_b400c_row2_col4" class="data row2 col4" >0.599483</td>
#     </tr>
#     <tr>
#       <th id="T_b400c_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_b400c_row3_col0" class="data row3 col0" >404.000000</td>
#       <td id="T_b400c_row3_col1" class="data row3 col1" >274.000000</td>
#       <td id="T_b400c_row3_col2" class="data row3 col2" >0.648968</td>
#       <td id="T_b400c_row3_col3" class="data row3 col3" >678.000000</td>
#       <td id="T_b400c_row3_col4" class="data row3 col4" >678.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Fits the explainer
explainer = shap.Explainer(clf_svc_grid.predict, X_test)
# Calculates the SHAP values
shap_values = explainer(X.sample(1000))
# Out:
# Permutation explainer: 1001it [2:11:54,  7.92s/it]

# %%
shap.summary_plot(shap_values)

# %% [markdown]
# #**SVC with balanced loss function**

# %%
classifier = SVC(class_weight='balanced',random_state = 0, probability = True)
C_range = [40]
kernel = ['rbf']
#degree=[1,2,3]
gamma_range = [0.01]
#gamma_range = np.append(np.logspace(-5,2,10),None)
params_grid_svc = dict(C = C_range, kernel = kernel, gamma = gamma_range)
clf_svc_grid = GridSearchCV(classifier,params_grid_svc,scoring='roc_auc',cv=3,verbose=3)
clf_svc_grid.fit(X_smote,Y_smote)
print(f"The best parameters are {clf_svc_grid.best_params_} with a score of {clf_svc_grid.best_score_}")
get_some_metric(clf_svc_grid)
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ......C=40, gamma=0.01, kernel=rbf;, score=0.726 total time=   2.5s
# [CV 2/3] END ......C=40, gamma=0.01, kernel=rbf;, score=0.740 total time=   2.5s
# [CV 3/3] END ......C=40, gamma=0.01, kernel=rbf;, score=0.732 total time=   2.4s
# The best parameters are {'C': 40, 'gamma': 0.01, 'kernel': 'rbf'} with a score of 0.7327078450841303

# %%
#get classification reports
Y_pred = clf_svc_grid.predict(X_test)
clf_rpt_test = pd.DataFrame(classification_report(Y_pred,Y_test,output_dict=True)).style.set_caption("Classification Report of test output")
#test classification report
clf_rpt_train = pd.DataFrame(classification_report(clf_svc_grid.predict(X_train),Y_train,output_dict=True)).style.set_caption("Classification Report of train set")

# %%
#train classification report
clf_rpt_train
# Out:
# <style type="text/css">
# </style>
# <table id="T_73bf6_" class="dataframe">
#   <caption>Classification Report of train set</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >accuracy</th>
#       <th class="col_heading level0 col3" >macro avg</th>
#       <th class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73bf6_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_73bf6_row0_col0" class="data row0 col0" >0.626574</td>
#       <td id="T_73bf6_row0_col1" class="data row0 col1" >0.713936</td>
#       <td id="T_73bf6_row0_col2" class="data row0 col2" >0.639749</td>
#       <td id="T_73bf6_row0_col3" class="data row0 col3" >0.670255</td>
#       <td id="T_73bf6_row0_col4" class="data row0 col4" >0.663684</td>
#     </tr>
#     <tr>
#       <th id="T_73bf6_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_73bf6_row1_col0" class="data row1 col0" >0.925000</td>
#       <td id="T_73bf6_row1_col1" class="data row1 col1" >0.253472</td>
#       <td id="T_73bf6_row1_col2" class="data row1 col2" >0.639749</td>
#       <td id="T_73bf6_row1_col3" class="data row1 col3" >0.589236</td>
#       <td id="T_73bf6_row1_col4" class="data row1 col4" >0.639749</td>
#     </tr>
#     <tr>
#       <th id="T_73bf6_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_73bf6_row2_col0" class="data row2 col0" >0.747088</td>
#       <td id="T_73bf6_row2_col1" class="data row2 col1" >0.374119</td>
#       <td id="T_73bf6_row2_col2" class="data row2 col2" >0.639749</td>
#       <td id="T_73bf6_row2_col3" class="data row2 col3" >0.560603</td>
#       <td id="T_73bf6_row2_col4" class="data row2 col4" >0.588659</td>
#     </tr>
#     <tr>
#       <th id="T_73bf6_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_73bf6_row3_col0" class="data row3 col0" >1560.000000</td>
#       <td id="T_73bf6_row3_col1" class="data row3 col1" >1152.000000</td>
#       <td id="T_73bf6_row3_col2" class="data row3 col2" >0.639749</td>
#       <td id="T_73bf6_row3_col3" class="data row3 col3" >2712.000000</td>
#       <td id="T_73bf6_row3_col4" class="data row3 col4" >2712.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
clf_rpt_test
# Out:
# <style type="text/css">
# </style>
# <table id="T_1ab4c_" class="dataframe">
#   <caption>Classification Report of test output</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >accuracy</th>
#       <th class="col_heading level0 col3" >macro avg</th>
#       <th class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ab4c_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_1ab4c_row0_col0" class="data row0 col0" >0.640625</td>
#       <td id="T_1ab4c_row0_col1" class="data row0 col1" >0.686275</td>
#       <td id="T_1ab4c_row0_col2" class="data row0 col2" >0.647493</td>
#       <td id="T_1ab4c_row0_col3" class="data row0 col3" >0.663450</td>
#       <td id="T_1ab4c_row0_col4" class="data row0 col4" >0.659275</td>
#     </tr>
#     <tr>
#       <th id="T_1ab4c_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_1ab4c_row1_col0" class="data row1 col0" >0.920200</td>
#       <td id="T_1ab4c_row1_col1" class="data row1 col1" >0.252708</td>
#       <td id="T_1ab4c_row1_col2" class="data row1 col2" >0.647493</td>
#       <td id="T_1ab4c_row1_col3" class="data row1 col3" >0.586454</td>
#       <td id="T_1ab4c_row1_col4" class="data row1 col4" >0.647493</td>
#     </tr>
#     <tr>
#       <th id="T_1ab4c_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_1ab4c_row2_col0" class="data row2 col0" >0.755374</td>
#       <td id="T_1ab4c_row2_col1" class="data row2 col1" >0.369393</td>
#       <td id="T_1ab4c_row2_col2" class="data row2 col2" >0.647493</td>
#       <td id="T_1ab4c_row2_col3" class="data row2 col3" >0.562383</td>
#       <td id="T_1ab4c_row2_col4" class="data row2 col4" >0.597680</td>
#     </tr>
#     <tr>
#       <th id="T_1ab4c_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_1ab4c_row3_col0" class="data row3 col0" >401.000000</td>
#       <td id="T_1ab4c_row3_col1" class="data row3 col1" >277.000000</td>
#       <td id="T_1ab4c_row3_col2" class="data row3 col2" >0.647493</td>
#       <td id="T_1ab4c_row3_col3" class="data row3 col3" >678.000000</td>
#       <td id="T_1ab4c_row3_col4" class="data row3 col4" >678.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Fits the explainer
explainer = shap.Explainer(clf_svc_grid.predict, X_test)
# Calculates the SHAP values
shap_values = explainer(X.sample(100))
shap.summary_plot(shap_values)
# Out:
# Permutation explainer: 101it [13:52,  8.41s/it]

# %% [markdown]
# #**Train test split for ensemble tree methods**

# %%
X=df2.drop(columns=['TenYearCHD'])
Y=df2['TenYearCHD']
#splitting the dataset

X_train, X_test, Y_train, Y_test = train_test_split( X,Y , test_size = 0.2, random_state = 0, stratify=Y)

#standardizing
#X_train = scaler.fit_transform(X_train)
#X_test = scaler.transform(X_test)
print(f'Before X_train : {X_train.shape}')
print(f'Before Y_train :\n{Y_train.value_counts()}')

#Handling class imbalance by oversampling it using smote and removinh tomek links
X_smote, Y_smote = SMOTETomek(random_state=42).fit_resample(X_train,Y_train)
print(f'After X_smote : {X_smote.shape}')
print(f'After Y_smote :\n{Y_smote.value_counts()}')
# Out:
# Before X_train : (2712, 14)
# Before Y_train :
# 0    2303
# 1     409
# Name: TenYearCHD, dtype: int64
# After X_smote : (4576, 14)
# After Y_smote :
# 0    2288
# 1    2288
# Name: TenYearCHD, dtype: int64

# %%
Y_test.value_counts()
# Out:
# 0    576
# 1    102
# Name: TenYearCHD, dtype: int64

# %% [markdown]
# #**LGBM implementation**

# %%
n_estimators = [10]
max_depth=[3]
learning_rate = [0.1]
param_dict_lr = dict(n_estimators = n_estimators, max_depth = max_depth, learning_rate = learning_rate)
lc = LGBMClassifier(random_state=31)
lgbm = GridSearchCV(lc,param_dict_lr,cv = 3, verbose=3, scoring='roc_auc')
lgbm.fit(X_smote,Y_smote)
print(f"The best parameters are {lgbm.best_params_} with a score of {lgbm.best_score_}")
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END learning_rate=0.1, max_depth=3, n_estimators=10;, score=0.769 total time=   0.1s
# [CV 2/3] END learning_rate=0.1, max_depth=3, n_estimators=10;, score=0.874 total time=   0.0s
# [CV 3/3] END learning_rate=0.1, max_depth=3, n_estimators=10;, score=0.823 total time=   0.0s
# The best parameters are {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 10} with a score of 0.8221641145632944

# %%
get_some_metric(lgbm)

# %%
#get classification reports
Y_pred = lgbm.predict(X_test)
clf_rpt_test = pd.DataFrame(classification_report(Y_pred,Y_test,output_dict=True)).style.set_caption("Classification Report of test output")
#test classification report
clf_rpt_train = pd.DataFrame(classification_report(lgbm.predict(X_train),Y_train,output_dict=True)).style.set_caption("Classification Report of train set")
#train classification report

# %%
clf_rpt_test
# Out:
# <style type="text/css">
# </style>
# <table id="T_ba6e1_" class="dataframe">
#   <caption>Classification Report of test output</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >accuracy</th>
#       <th class="col_heading level0 col3" >macro avg</th>
#       <th class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba6e1_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_ba6e1_row0_col0" class="data row0 col0" >0.600694</td>
#       <td id="T_ba6e1_row0_col1" class="data row0 col1" >0.617647</td>
#       <td id="T_ba6e1_row0_col2" class="data row0 col2" >0.603245</td>
#       <td id="T_ba6e1_row0_col3" class="data row0 col3" >0.609171</td>
#       <td id="T_ba6e1_row0_col4" class="data row0 col4" >0.608021</td>
#     </tr>
#     <tr>
#       <th id="T_ba6e1_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_ba6e1_row1_col0" class="data row1 col0" >0.898701</td>
#       <td id="T_ba6e1_row1_col1" class="data row1 col1" >0.215017</td>
#       <td id="T_ba6e1_row1_col2" class="data row1 col2" >0.603245</td>
#       <td id="T_ba6e1_row1_col3" class="data row1 col3" >0.556859</td>
#       <td id="T_ba6e1_row1_col4" class="data row1 col4" >0.603245</td>
#     </tr>
#     <tr>
#       <th id="T_ba6e1_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_ba6e1_row2_col0" class="data row2 col0" >0.720083</td>
#       <td id="T_ba6e1_row2_col1" class="data row2 col1" >0.318987</td>
#       <td id="T_ba6e1_row2_col2" class="data row2 col2" >0.603245</td>
#       <td id="T_ba6e1_row2_col3" class="data row2 col3" >0.519535</td>
#       <td id="T_ba6e1_row2_col4" class="data row2 col4" >0.546748</td>
#     </tr>
#     <tr>
#       <th id="T_ba6e1_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_ba6e1_row3_col0" class="data row3 col0" >385.000000</td>
#       <td id="T_ba6e1_row3_col1" class="data row3 col1" >293.000000</td>
#       <td id="T_ba6e1_row3_col2" class="data row3 col2" >0.603245</td>
#       <td id="T_ba6e1_row3_col3" class="data row3 col3" >678.000000</td>
#       <td id="T_ba6e1_row3_col4" class="data row3 col4" >678.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
clf_rpt_train
# Out:
# <style type="text/css">
# </style>
# <table id="T_c0cc4_" class="dataframe">
#   <caption>Classification Report of train set</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >accuracy</th>
#       <th class="col_heading level0 col3" >macro avg</th>
#       <th class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0cc4_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_c0cc4_row0_col0" class="data row0 col0" >0.603126</td>
#       <td id="T_c0cc4_row0_col1" class="data row0 col1" >0.709046</td>
#       <td id="T_c0cc4_row0_col2" class="data row0 col2" >0.619100</td>
#       <td id="T_c0cc4_row0_col3" class="data row0 col3" >0.656086</td>
#       <td id="T_c0cc4_row0_col4" class="data row0 col4" >0.650150</td>
#     </tr>
#     <tr>
#       <th id="T_c0cc4_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_c0cc4_row1_col0" class="data row1 col0" >0.921088</td>
#       <td id="T_c0cc4_row1_col1" class="data row1 col1" >0.240864</td>
#       <td id="T_c0cc4_row1_col2" class="data row1 col2" >0.619100</td>
#       <td id="T_c0cc4_row1_col3" class="data row1 col3" >0.580976</td>
#       <td id="T_c0cc4_row1_col4" class="data row1 col4" >0.619100</td>
#     </tr>
#     <tr>
#       <th id="T_c0cc4_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_c0cc4_row2_col0" class="data row2 col0" >0.728943</td>
#       <td id="T_c0cc4_row2_col1" class="data row2 col1" >0.359578</td>
#       <td id="T_c0cc4_row2_col2" class="data row2 col2" >0.619100</td>
#       <td id="T_c0cc4_row2_col3" class="data row2 col3" >0.544260</td>
#       <td id="T_c0cc4_row2_col4" class="data row2 col4" >0.564962</td>
#     </tr>
#     <tr>
#       <th id="T_c0cc4_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_c0cc4_row3_col0" class="data row3 col0" >1508.000000</td>
#       <td id="T_c0cc4_row3_col1" class="data row3 col1" >1204.000000</td>
#       <td id="T_c0cc4_row3_col2" class="data row3 col2" >0.619100</td>
#       <td id="T_c0cc4_row3_col3" class="data row3 col3" >2712.000000</td>
#       <td id="T_c0cc4_row3_col4" class="data row3 col4" >2712.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Fits the explainer
explainer = shap.Explainer(lgbm.predict, X_test)
# Calculates the SHAP values
shap_values = explainer(X)
# Out:
# Permutation explainer: 3391it [03:21, 15.97it/s]

# %%
shap.plots.beeswarm(shap_values)

# %% [markdown]
# #**XGRFB Implementation**

# %%
from xgboost import XGBRFClassifier
from sklearn.model_selection import RandomizedSearchCV
clf = XGBRFClassifier(weight_class='balanced', silent=True, random_state=3)

# HYperparameter Grid
grid = {'n_estimators' : [100],
        'max_depth' : [3],
        'min_samples_split' : [40],
        'min_samples_leaf' : [50],
        'eta' : [0.01]}

# GridSearch to find the best parameters
xgb = RandomizedSearchCV(estimator = clf, param_distributions = grid, scoring = 'roc_auc', cv=3, verbose=3)
xgb.fit(X_smote, Y_smote)
print(f"The best parameters are {xgb.best_params_} with a score of {xgb.best_score_}")
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END eta=0.01, max_depth=3, min_samples_leaf=50, min_samples_split=40, n_estimators=100;, score=0.769 total time=   0.2s
# [CV 2/3] END eta=0.01, max_depth=3, min_samples_leaf=50, min_samples_split=40, n_estimators=100;, score=0.816 total time=   0.1s
# [CV 3/3] END eta=0.01, max_depth=3, min_samples_leaf=50, min_samples_split=40, n_estimators=100;, score=0.786 total time=   0.1s
# The best parameters are {'n_estimators': 100, 'min_samples_split': 40, 'min_samples_leaf': 50, 'max_depth': 3, 'eta': 0.01} with a score of 0.7904574200520437

# %%
get_some_metric(xgb)

# %%
#get classification reports
Y_pred = xgb.predict(X_test)
clf_rpt_test = pd.DataFrame(classification_report(Y_pred,Y_test,output_dict=True)).style.set_caption("Classification Report of test output")
#test classification report
clf_rpt_train = pd.DataFrame(classification_report(xgb.predict(X_train),Y_train,output_dict=True)).style.set_caption("Classification Report of train set")
#train classification report

# %%
clf_rpt_test
# Out:
# <style type="text/css">
# </style>
# <table id="T_d78d0_" class="dataframe">
#   <caption>Classification Report of test output</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >accuracy</th>
#       <th class="col_heading level0 col3" >macro avg</th>
#       <th class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d78d0_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_d78d0_row0_col0" class="data row0 col0" >0.585069</td>
#       <td id="T_d78d0_row0_col1" class="data row0 col1" >0.676471</td>
#       <td id="T_d78d0_row0_col2" class="data row0 col2" >0.598820</td>
#       <td id="T_d78d0_row0_col3" class="data row0 col3" >0.630770</td>
#       <td id="T_d78d0_row0_col4" class="data row0 col4" >0.626591</td>
#     </tr>
#     <tr>
#       <th id="T_d78d0_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_d78d0_row1_col0" class="data row1 col0" >0.910811</td>
#       <td id="T_d78d0_row1_col1" class="data row1 col1" >0.224026</td>
#       <td id="T_d78d0_row1_col2" class="data row1 col2" >0.598820</td>
#       <td id="T_d78d0_row1_col3" class="data row1 col3" >0.567418</td>
#       <td id="T_d78d0_row1_col4" class="data row1 col4" >0.598820</td>
#     </tr>
#     <tr>
#       <th id="T_d78d0_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_d78d0_row2_col0" class="data row2 col0" >0.712474</td>
#       <td id="T_d78d0_row2_col1" class="data row2 col1" >0.336585</td>
#       <td id="T_d78d0_row2_col2" class="data row2 col2" >0.598820</td>
#       <td id="T_d78d0_row2_col3" class="data row2 col3" >0.524529</td>
#       <td id="T_d78d0_row2_col4" class="data row2 col4" >0.541716</td>
#     </tr>
#     <tr>
#       <th id="T_d78d0_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_d78d0_row3_col0" class="data row3 col0" >370.000000</td>
#       <td id="T_d78d0_row3_col1" class="data row3 col1" >308.000000</td>
#       <td id="T_d78d0_row3_col2" class="data row3 col2" >0.598820</td>
#       <td id="T_d78d0_row3_col3" class="data row3 col3" >678.000000</td>
#       <td id="T_d78d0_row3_col4" class="data row3 col4" >678.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
clf_rpt_train
# Out:
# <style type="text/css">
# </style>
# <table id="T_7b04b_" class="dataframe">
#   <caption>Classification Report of train set</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >accuracy</th>
#       <th class="col_heading level0 col3" >macro avg</th>
#       <th class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b04b_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_7b04b_row0_col0" class="data row0 col0" >0.591403</td>
#       <td id="T_7b04b_row0_col1" class="data row0 col1" >0.726161</td>
#       <td id="T_7b04b_row0_col2" class="data row0 col2" >0.611726</td>
#       <td id="T_7b04b_row0_col3" class="data row0 col3" >0.658782</td>
#       <td id="T_7b04b_row0_col4" class="data row0 col4" >0.652919</td>
#     </tr>
#     <tr>
#       <th id="T_7b04b_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_7b04b_row1_col0" class="data row1 col0" >0.924016</td>
#       <td id="T_7b04b_row1_col1" class="data row1 col1" >0.239903</td>
#       <td id="T_7b04b_row1_col2" class="data row1 col2" >0.611726</td>
#       <td id="T_7b04b_row1_col3" class="data row1 col3" >0.581960</td>
#       <td id="T_7b04b_row1_col4" class="data row1 col4" >0.611726</td>
#     </tr>
#     <tr>
#       <th id="T_7b04b_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_7b04b_row2_col0" class="data row2 col0" >0.721207</td>
#       <td id="T_7b04b_row2_col1" class="data row2 col1" >0.360656</td>
#       <td id="T_7b04b_row2_col2" class="data row2 col2" >0.611726</td>
#       <td id="T_7b04b_row2_col3" class="data row2 col3" >0.540932</td>
#       <td id="T_7b04b_row2_col4" class="data row2 col4" >0.556619</td>
#     </tr>
#     <tr>
#       <th id="T_7b04b_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_7b04b_row3_col0" class="data row3 col0" >1474.000000</td>
#       <td id="T_7b04b_row3_col1" class="data row3 col1" >1238.000000</td>
#       <td id="T_7b04b_row3_col2" class="data row3 col2" >0.611726</td>
#       <td id="T_7b04b_row3_col3" class="data row3 col3" >2712.000000</td>
#       <td id="T_7b04b_row3_col4" class="data row3 col4" >2712.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Fits the explainer
explainer = shap.Explainer(xgb.predict, X_test)
# Calculates the SHAP values
shap_values = explainer(X)
# Out:
# Permutation explainer: 3391it [06:31,  8.42it/s]

# %%
shap.plots.beeswarm(shap_values)

# %% [markdown]
# #**Random Forest Implementation**

# %%
from sklearn.ensemble import RandomForestClassifier
n_estimators=[100]
criterion = ['entropy']
max_depth = [3]
min_sample_split = [100]
min_sample_leaf = [40]
params_grid = dict(n_estimators = n_estimators,
                   criterion = criterion,
                   max_depth = max_depth,
                   min_samples_split = min_sample_split,
                   min_samples_leaf = min_sample_leaf)
RF=RandomForestClassifier(class_weight='balanced')
RF_model = GridSearchCV(RF, param_grid = params_grid, scoring='roc_auc', cv=3, verbose = 3)
RF_model.fit(X_smote,Y_smote)
print(f"The best parameters are {RF_model.best_params_} with a score of {RF_model.best_score_}")
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END criterion=entropy, max_depth=3, min_samples_leaf=40, min_samples_split=100, n_estimators=100;, score=0.742 total time=   0.3s
# [CV 2/3] END criterion=entropy, max_depth=3, min_samples_leaf=40, min_samples_split=100, n_estimators=100;, score=0.810 total time=   0.3s
# [CV 3/3] END criterion=entropy, max_depth=3, min_samples_leaf=40, min_samples_split=100, n_estimators=100;, score=0.815 total time=   0.3s
# The best parameters are {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 40, 'min_samples_split': 100, 'n_estimators': 100} with a score of 0.7891577062131726

# %%
get_some_metric(RF_model)

# %%
#get classification reports
Y_pred = RF_model.predict(X_test)
clf_rpt_test = pd.DataFrame(classification_report(Y_pred,Y_test,output_dict=True)).style.set_caption("Classification Report of test output")
#test classification report
clf_rpt_train = pd.DataFrame(classification_report(RF_model.predict(X_train),Y_train,output_dict=True)).style.set_caption("Classification Report of train set")
#train classification report

# %%
clf_rpt_test
# Out:
# <style type="text/css">
# </style>
# <table id="T_4e551_" class="dataframe">
#   <caption>Classification Report of test output</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >accuracy</th>
#       <th class="col_heading level0 col3" >macro avg</th>
#       <th class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e551_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_4e551_row0_col0" class="data row0 col0" >0.631944</td>
#       <td id="T_4e551_row0_col1" class="data row0 col1" >0.607843</td>
#       <td id="T_4e551_row0_col2" class="data row0 col2" >0.628319</td>
#       <td id="T_4e551_row0_col3" class="data row0 col3" >0.619894</td>
#       <td id="T_4e551_row0_col4" class="data row0 col4" >0.622204</td>
#     </tr>
#     <tr>
#       <th id="T_4e551_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_4e551_row1_col0" class="data row1 col0" >0.900990</td>
#       <td id="T_4e551_row1_col1" class="data row1 col1" >0.226277</td>
#       <td id="T_4e551_row1_col2" class="data row1 col2" >0.628319</td>
#       <td id="T_4e551_row1_col3" class="data row1 col3" >0.563634</td>
#       <td id="T_4e551_row1_col4" class="data row1 col4" >0.628319</td>
#     </tr>
#     <tr>
#       <th id="T_4e551_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_4e551_row2_col0" class="data row2 col0" >0.742857</td>
#       <td id="T_4e551_row2_col1" class="data row2 col1" >0.329787</td>
#       <td id="T_4e551_row2_col2" class="data row2 col2" >0.628319</td>
#       <td id="T_4e551_row2_col3" class="data row2 col3" >0.536322</td>
#       <td id="T_4e551_row2_col4" class="data row2 col4" >0.575923</td>
#     </tr>
#     <tr>
#       <th id="T_4e551_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_4e551_row3_col0" class="data row3 col0" >404.000000</td>
#       <td id="T_4e551_row3_col1" class="data row3 col1" >274.000000</td>
#       <td id="T_4e551_row3_col2" class="data row3 col2" >0.628319</td>
#       <td id="T_4e551_row3_col3" class="data row3 col3" >678.000000</td>
#       <td id="T_4e551_row3_col4" class="data row3 col4" >678.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
clf_rpt_train
# Out:
# <style type="text/css">
# </style>
# <table id="T_1cee4_" class="dataframe">
#   <caption>Classification Report of train set</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >accuracy</th>
#       <th class="col_heading level0 col3" >macro avg</th>
#       <th class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1cee4_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_1cee4_row0_col0" class="data row0 col0" >0.651324</td>
#       <td id="T_1cee4_row0_col1" class="data row0 col1" >0.650367</td>
#       <td id="T_1cee4_row0_col2" class="data row0 col2" >0.651180</td>
#       <td id="T_1cee4_row0_col3" class="data row0 col3" >0.650846</td>
#       <td id="T_1cee4_row0_col4" class="data row0 col4" >0.650947</td>
#     </tr>
#     <tr>
#       <th id="T_1cee4_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_1cee4_row1_col0" class="data row1 col0" >0.912964</td>
#       <td id="T_1cee4_row1_col1" class="data row1 col1" >0.248831</td>
#       <td id="T_1cee4_row1_col2" class="data row1 col2" >0.651180</td>
#       <td id="T_1cee4_row1_col3" class="data row1 col3" >0.580897</td>
#       <td id="T_1cee4_row1_col4" class="data row1 col4" >0.651180</td>
#     </tr>
#     <tr>
#       <th id="T_1cee4_level0_row2" class="row_heading level0 row2" >f1-score</th>
#       <td id="T_1cee4_row2_col0" class="data row2 col0" >0.760264</td>
#       <td id="T_1cee4_row2_col1" class="data row2 col1" >0.359946</td>
#       <td id="T_1cee4_row2_col2" class="data row2 col2" >0.651180</td>
#       <td id="T_1cee4_row2_col3" class="data row2 col3" >0.560105</td>
#       <td id="T_1cee4_row2_col4" class="data row2 col4" >0.602469</td>
#     </tr>
#     <tr>
#       <th id="T_1cee4_level0_row3" class="row_heading level0 row3" >support</th>
#       <td id="T_1cee4_row3_col0" class="data row3 col0" >1643.000000</td>
#       <td id="T_1cee4_row3_col1" class="data row3 col1" >1069.000000</td>
#       <td id="T_1cee4_row3_col2" class="data row3 col2" >0.651180</td>
#       <td id="T_1cee4_row3_col3" class="data row3 col3" >2712.000000</td>
#       <td id="T_1cee4_row3_col4" class="data row3 col4" >2712.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Fits the explainer
explainer = shap.Explainer(RF_model.predict, X_test)
# Calculates the SHAP values
shap_values = explainer(X)
# Out:
# Permutation explainer: 3391it [22:44,  2.47it/s]

# %%
shap.plots.beeswarm(shap_values)

# %% [markdown]
# #**Neural Network model**

# %%
#preparing dataset
X = df2.drop(columns=['TenYearCHD'])
Y = df2['TenYearCHD']
#train test split
X_train, X_test, Y_train, Y_test = train_test_split( X,Y , test_size = 0.2, random_state = 0, stratify=Y)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train.shape,X_test.shape
# Out:
# ((2712, 14), (678, 14))

# %%
#Creating ANN
# !pip install keras
from keras.layers import Lambda
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU,ReLU
#from tensorflow.keras.layers import LeakyRelU
from tensorflow.keras.layers import Dropout
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (2.8.0)

# %%
#Initializing ANN
classifier=Sequential()
#Adding input layers
classifier.add(Dense(units=11,activation='relu'))
#Adding hidden layers
classifier.add(Dense(units=64,activation='relu'))
classifier.add(Dense(units=8,activation='relu'))
#output layer
classifier.add(Dense(units=1,activation='sigmoid'))

# %%
classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['binary_accuracy'])

# %%
#early stopping
import tensorflow as tf
ES = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    min_delta=0.001,
    patience=15,
    verbose=1,
    mode='auto',
    baseline=None,
    restore_best_weights=True
)

# %%
model = classifier.fit(X_train,Y_train,validation_split = 0.33, batch_size = 25, epochs = 100,callbacks=ES)
# Out:
# Epoch 1/100
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3954 - binary_accuracy: 0.8431 - val_loss: 0.3767 - val_binary_accuracy: 0.8581
# Epoch 2/100
# 73/73 [==============================] - 0s 3ms/step - loss: 0.3854 - binary_accuracy: 0.8498 - val_loss: 0.3746 - val_binary_accuracy: 0.8626
# Epoch 3/100
# 73/73 [==============================] - 0s 3ms/step - loss: 0.3848 - binary_accuracy: 0.8520 - val_loss: 0.3748 - val_binary_accuracy: 0.8626
# Epoch 4/100
# 73/73 [==============================] - 0s 3ms/step - loss: 0.3842 - binary_accuracy: 0.8498 - val_loss: 0.3758 - val_binary_accuracy: 0.8626
# Epoch 5/100
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3847 - binary_accuracy: 0.8509 - val_loss: 0.3756 - val_binary_accuracy: 0.8637
# Epoch 6/100
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3841 - binary_accuracy: 0.8520 - val_loss: 0.3761 - val_binary_accuracy: 0.8592
# Epoch 7/100
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3836 - binary_accuracy: 0.8514 - val_loss: 0.3749 - val_binary_accuracy: 0.8637
# Epoch 8/100
# 73/73 [==============================] - 0s 3ms/step - loss: 0.3832 - binary_accuracy: 0.8525 - val_loss: 0.3768 - val_binary_accuracy: 0.8570
# Epoch 9/100
# 73/73 [==============================] - 0s 3ms/step - loss: 0.3852 - binary_accuracy: 0.8547 - val_loss: 0.3775 - val_binary_accuracy: 0.8626
# Epoch 10/100
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3821 - binary_accuracy: 0.8553 - val_loss: 0.3779 - val_binary_accuracy: 0.8559
# Epoch 11/100
# 73/73 [==============================] - 0s 3ms/step - loss: 0.3840 - binary_accuracy: 0.8520 - val_loss: 0.3794 - val_binary_accuracy: 0.8547
# Epoch 12/100
# 73/73 [==============================] - 0s 3ms/step - loss: 0.3825 - binary_accuracy: 0.8542 - val_loss: 0.3763 - val_binary_accuracy: 0.8615
# Epoch 13/100
# 73/73 [==============================] - 0s 3ms/step - loss: 0.3821 - binary_accuracy: 0.8542 - val_loss: 0.3772 - val_binary_accuracy: 0.8615
# Epoch 14/100
# 73/73 [==============================] - 0s 3ms/step - loss: 0.3823 - binary_accuracy: 0.8531 - val_loss: 0.3773 - val_binary_accuracy: 0.8615
# Epoch 15/100
# 73/73 [==============================] - 0s 3ms/step - loss: 0.3807 - binary_accuracy: 0.8564 - val_loss: 0.3777 - val_binary_accuracy: 0.8581
# Epoch 16/100
# 73/73 [==============================] - 0s 3ms/step - loss: 0.3815 - binary_accuracy: 0.8520 - val_loss: 0.3776 - val_binary_accuracy: 0.8637
# Epoch 17/100
# 51/73 [===================>..........] - ETA: 0s - loss: 0.3838 - binary_accuracy: 0.8549Restoring model weights from the end of the best epoch: 2.
# 73/73 [==============================] - 0s 3ms/step - loss: 0.3813 - binary_accuracy: 0.8547 - val_loss: 0.3774 - val_binary_accuracy: 0.8603
# Epoch 17: early stopping

# %%
model.history.keys()
# Out:
# dict_keys(['loss', 'binary_accuracy', 'val_loss', 'val_binary_accuracy'])

# %%
Y_pred = classifier.predict(X_test)
Y_pred = (Y_pred >=0.15)

# %%
sns.heatmap(confusion_matrix(Y_pred,Y_test),annot=True, cmap='coolwarm',fmt='g')
plt.gcf().set_size_inches(5,5)
plt.ylabel('Predicted Label')
plt.xlabel('True Label')
plt.title('test_data_confusion_matrix',weight='bold')
# Out:
# Text(0.5, 1.0, 'test_data_confusion_matrix')

# %%
# Fits the explainer
explainer = shap.Explainer(classifier.predict, X_test)
# Calculates the SHAP values
shap_values = explainer(X)
# Out:
# Permutation explainer: 3391it [2:43:01,  2.89s/it]

# %%
shap.plots.beeswarm(shap_values)

# %%
#trying with synthetic dataset
#Initializing ANN
classifier=Sequential()
#Adding input layers
classifier.add(Dense(units=11,activation='relu'))
#Adding hidden layers
classifier.add(Dense(units=10,activation='relu'))
classifier.add(Dense(units=10,activation='relu'))
classifier.add(Dense(units=10,activation='relu'))
#output layer
classifier.add(Dense(units=1,activation='sigmoid'))

classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['binary_accuracy'])

model = classifier.fit(X_smote,Y_smote,validation_split = 0.33, batch_size = 25, epochs = 100,callbacks=ES)
# Out:
# Epoch 1/100
# 104/104 [==============================] - 2s 11ms/step - loss: 0.6357 - binary_accuracy: 0.6957 - val_loss: 1.2125 - val_binary_accuracy: 0.0000e+00
# Epoch 2/100
# 104/104 [==============================] - 0s 4ms/step - loss: 0.5611 - binary_accuracy: 0.7465 - val_loss: 1.1631 - val_binary_accuracy: 0.0000e+00
# Epoch 3/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.5359 - binary_accuracy: 0.7465 - val_loss: 1.3294 - val_binary_accuracy: 0.0000e+00
# Epoch 4/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.5286 - binary_accuracy: 0.7465 - val_loss: 1.3047 - val_binary_accuracy: 0.0000e+00
# Epoch 5/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.5228 - binary_accuracy: 0.7465 - val_loss: 1.1656 - val_binary_accuracy: 0.0000e+00
# Epoch 6/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.5183 - binary_accuracy: 0.7504 - val_loss: 1.2243 - val_binary_accuracy: 0.0281
# Epoch 7/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.5151 - binary_accuracy: 0.7546 - val_loss: 1.1633 - val_binary_accuracy: 0.1703
# Epoch 8/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.5135 - binary_accuracy: 0.7535 - val_loss: 1.2061 - val_binary_accuracy: 0.1492
# Epoch 9/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.5093 - binary_accuracy: 0.7589 - val_loss: 1.1474 - val_binary_accuracy: 0.2023
# Epoch 10/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.5058 - binary_accuracy: 0.7592 - val_loss: 1.2906 - val_binary_accuracy: 0.1016
# Epoch 11/100
# 104/104 [==============================] - 0s 4ms/step - loss: 0.5039 - binary_accuracy: 0.7596 - val_loss: 1.1658 - val_binary_accuracy: 0.1898
# Epoch 12/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.5008 - binary_accuracy: 0.7650 - val_loss: 1.2043 - val_binary_accuracy: 0.1977
# Epoch 13/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.4997 - binary_accuracy: 0.7693 - val_loss: 1.0738 - val_binary_accuracy: 0.2930
# Epoch 14/100
# 104/104 [==============================] - 0s 4ms/step - loss: 0.4975 - binary_accuracy: 0.7685 - val_loss: 1.2759 - val_binary_accuracy: 0.1367
# Epoch 15/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.4951 - binary_accuracy: 0.7669 - val_loss: 1.2235 - val_binary_accuracy: 0.2000
# Epoch 16/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.4948 - binary_accuracy: 0.7704 - val_loss: 1.1864 - val_binary_accuracy: 0.2195
# Epoch 17/100
# 104/104 [==============================] - 0s 4ms/step - loss: 0.4926 - binary_accuracy: 0.7716 - val_loss: 1.1963 - val_binary_accuracy: 0.2273
# Epoch 18/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.4905 - binary_accuracy: 0.7720 - val_loss: 1.0424 - val_binary_accuracy: 0.2727
# Epoch 19/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.4931 - binary_accuracy: 0.7662 - val_loss: 1.3521 - val_binary_accuracy: 0.1250
# Epoch 20/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.4898 - binary_accuracy: 0.7747 - val_loss: 1.0324 - val_binary_accuracy: 0.2891
# Epoch 21/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.4901 - binary_accuracy: 0.7716 - val_loss: 0.9859 - val_binary_accuracy: 0.3039
# Epoch 22/100
# 104/104 [==============================] - 0s 4ms/step - loss: 0.4908 - binary_accuracy: 0.7673 - val_loss: 1.1594 - val_binary_accuracy: 0.2203
# Epoch 23/100
# 104/104 [==============================] - 0s 4ms/step - loss: 0.4890 - binary_accuracy: 0.7743 - val_loss: 1.1990 - val_binary_accuracy: 0.2109
# Epoch 24/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.4875 - binary_accuracy: 0.7731 - val_loss: 1.2183 - val_binary_accuracy: 0.2188
# Epoch 25/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.4871 - binary_accuracy: 0.7739 - val_loss: 1.0975 - val_binary_accuracy: 0.2727
# Epoch 26/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.4872 - binary_accuracy: 0.7723 - val_loss: 1.2398 - val_binary_accuracy: 0.2133
# Epoch 27/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.4860 - binary_accuracy: 0.7666 - val_loss: 1.0217 - val_binary_accuracy: 0.2930
# Epoch 28/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.4879 - binary_accuracy: 0.7685 - val_loss: 1.1732 - val_binary_accuracy: 0.2000
# Epoch 29/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.4854 - binary_accuracy: 0.7696 - val_loss: 1.0240 - val_binary_accuracy: 0.2906
# Epoch 30/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.4855 - binary_accuracy: 0.7700 - val_loss: 1.0920 - val_binary_accuracy: 0.2586
# Epoch 31/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.4855 - binary_accuracy: 0.7681 - val_loss: 1.1262 - val_binary_accuracy: 0.2555
# Epoch 32/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.4863 - binary_accuracy: 0.7727 - val_loss: 1.2195 - val_binary_accuracy: 0.2125
# Epoch 33/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.4851 - binary_accuracy: 0.7750 - val_loss: 1.1711 - val_binary_accuracy: 0.2391
# Epoch 34/100
# 104/104 [==============================] - 0s 4ms/step - loss: 0.4850 - binary_accuracy: 0.7723 - val_loss: 1.1866 - val_binary_accuracy: 0.2008
# Epoch 35/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.4850 - binary_accuracy: 0.7704 - val_loss: 1.1710 - val_binary_accuracy: 0.2258
# Epoch 36/100
#  85/104 [=======================>......] - ETA: 0s - loss: 0.4850 - binary_accuracy: 0.7765Restoring model weights from the end of the best epoch: 21.
# 104/104 [==============================] - 0s 3ms/step - loss: 0.4846 - binary_accuracy: 0.7758 - val_loss: 1.1987 - val_binary_accuracy: 0.2289
# Epoch 36: early stopping

# %%
Y_pred = classifier.predict(X_test)
Y_pred = (Y_pred >=0.35)
sns.heatmap(confusion_matrix(Y_pred,Y_test),annot=True, cmap='coolwarm',fmt='g')
plt.gcf().set_size_inches(5,5)
plt.ylabel('Predicted Label')
plt.xlabel('True Label')
plt.title('test_data_confusion_matrix',weight='bold')
# Out:
# Text(0.5, 1.0, 'test_data_confusion_matrix')

# %% [markdown]
# #**Conclusion**

# %% [markdown]
# Among all if we want simplicity logistic regression can be used. If we want high results we can use SVC(2) or XGRFB model, among them I prefer XGRFB model because it could catch the essence of the data properly.
